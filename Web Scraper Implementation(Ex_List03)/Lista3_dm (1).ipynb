# %%
from datetime import datetime

def convert_date(date_string):
    # Parse the date string into a datetime object
    date_o = datetime.strptime(date_string, " %d/%m/%Y às %H:%M ")
    # Convert the datetime object to a string in the format suitable for the database
    db_friendly_date = date_o.strftime("%Y-%m-%d %H:%M:%S")

    return db_friendly_date

# %%
def find_paragraphs(post_content):

  texto_noticia = ""

  paragraphs = post_content.find_all('p', recursive=False)

  for p in paragraphs:
      # Check if the parent of the <p> tag has class 'read__too'
      parent_classes = [c.get('class', []) for c in p.parents]
      if not any('read__too' in classes for classes in parent_classes):
          texto_noticia += p.get_text() + " "

  return texto_noticia

# %%
def topicos_tidy(topicos_content):

  if topicos_content is None:
    return None

  #Extract the text content and split it by whitespace characters
  topicos_list = topicos_content.get_text(separator=',').split(',')

  #Remove any empty strings or whitespace-only strings from the list
  topicos_list = [topic.strip() for topic in topicos_list if topic.strip()]

  #Join the topics back together with commas
  topicos = ', '.join(topicos_list)

  return topicos

# %%
import requests
from bs4 import BeautifulSoup

def extractor(noticia):

  #subdivisoes de interesse da miniatura
  main_tags = noticia.find('a', attrs={'class': 'home__list__tag'})

  #title---
  title = main_tags.text
  title = title.strip()

  #subtitle---
  subtitle = main_tags.get('title')

  #date---
  date = noticia.find('span', attrs={'class': 'home__title__date'})
  date = convert_date(date.text)

  #link---
  news_link = main_tags.get('href')

  #going inside the link of the news------ANOTHER PAGE
  response_B = requests.get(news_link)
  html_content_B = response_B.content
  site_B = BeautifulSoup(html_content_B, 'html.parser')

  #autor---
  try:
    autor_tag = site_B.find('span', attrs={'class': 'author__group'}).find('a')

    if autor_tag is not None:
      autor = autor_tag.text
    else:
      autor = None
  except AttributeError as e:
    autor = None

  #texto da notícia---
  #tag com o conteudo do post
  post_content = site_B.find('div', attrs={'class': 'post__content'})
  texto_noticia = find_paragraphs(post_content)

  #Tópicos da noticia---
  topicos_content = post_content.find('ul', attrs={'class': 'tags__list'})
  topicos = topicos_tidy(topicos_content)

  #retorna os atributos de interesse
  return(title, subtitle, autor, date, texto_noticia, topicos, news_link)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

#open CSV file in write mode
with open('Lista3_data_dm.csv', 'w', newline='', encoding='utf-8') as csvfile:
  #csv writer object
  writer = csv.writer(csvfile)
  # Write the header row
  writer.writerow(['Título', 'Subtítulo', 'Autor', 'Data', 'Conteudo_texto', 'Tópicos', 'Link'])


  for i in range(1, 78):

    page_link = f'https://www.cnnbrasil.com.br/ultimas-noticias/pagina/{i}/'
    print(page_link)

    response = requests.get(page_link)

    html_content = response.content
    site = BeautifulSoup(html_content, 'html.parser')

    #html divisão de interesse
    noticias = site.findAll('li', attrs={'class': 'home__list__item'})

    for noticia in noticias:
      A,B,C,D,E,F,G = extractor(noticia)
      writer.writerow([A, B, C, D, E, F, G])


df = pd.read_csv('Lista3_data_dm.csv')


duplicate_rows = df[df.duplicated(keep=False)]

#duplicates
print("Duplicate Rows:")
print(duplicate_rows)

#remove duplicates
df.drop_duplicates(inplace=True)

#Write the DataFrame back to the CSV file
df.to_csv('Lista3_data_dm.csv', index=False, encoding='utf-8')
# Out:
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/1/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/2/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/3/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/4/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/5/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/6/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/7/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/8/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/9/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/10/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/11/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/12/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/13/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/14/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/15/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/16/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/17/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/18/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/19/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/20/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/21/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/22/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/23/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/24/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/25/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/26/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/27/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/28/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/29/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/30/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/31/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/32/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/33/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/34/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/35/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/36/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/37/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/38/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/39/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/40/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/41/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/42/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/43/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/44/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/45/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/46/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/47/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/48/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/49/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/50/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/51/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/52/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/53/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/54/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/55/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/56/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/57/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/58/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/59/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/60/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/61/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/62/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/63/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/64/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/65/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/66/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/67/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/68/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/69/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/70/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/71/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/72/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/73/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/74/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/75/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/76/
# https://www.cnnbrasil.com.br/ultimas-noticias/pagina/77/
# Duplicate Rows:
#                                                 Título  \
# 117  Doria terá de pagar R$ 103 mil a Marisa Monte ...
# 118  Goleiro Marcelo Grohe volta a ficar no radar d...
# 119  Pagamento dos dividendos da Petrobras depende ...
# 120  Doria terá de pagar R$ 103 mil a Marisa Monte ...
# 121  Goleiro Marcelo Grohe volta a ficar no radar d...
# 122  Pagamento dos dividendos da Petrobras depende ...
# 419  Franjas: veja como usar o item que é tendência...
# 420  Franjas: veja como usar o item que é tendência...
# 719  Zayn divulga tracklist completa de novo álbum;...
# 720  Zayn divulga tracklist completa de novo álbum;...
#
#                                              Subtítulo              Autor  \
# 117  Político utilizou música da dupla em vídeo pub...                NaN
# 118  Tricolor Gaúcho estuda repatriar o arqueiro íd...     Mauri Dorneles
# 119  Presidente do colegiado, Pietro Mendes, foi af...                NaN
# 120  Político utilizou música da dupla em vídeo pub...                NaN
# 121  Tricolor Gaúcho estuda repatriar o arqueiro íd...     Mauri Dorneles
# 122  Presidente do colegiado, Pietro Mendes, foi af...                NaN
# 419  Com a estética cowboy em evidências, looks com...  Caroline Ferreira
# 420  Com a estética cowboy em evidências, looks com...  Caroline Ferreira
# 719  Cantor lança quarto disco de estúdio em maio; ...      Nicoly Bastos
# 720  Cantor lança quarto disco de estúdio em maio; ...      Nicoly Bastos
#
#                     Data                                     Conteudo_texto  \
# 117  2024-04-12 19:54:00  O ex-governador e ex-prefeito de São Paulo Joã...
# 118  2024-04-12 19:47:00  Sem conseguir afirmar um goleiro em 2024, o Gr...
# 119  2024-04-12 19:41:00  O governo tem até a próxima sexta-feira (19) p...
# 120  2024-04-12 19:54:00  O ex-governador e ex-prefeito de São Paulo Joã...
# 121  2024-04-12 19:47:00  Sem conseguir afirmar um goleiro em 2024, o Gr...
# 122  2024-04-12 19:41:00  O governo tem até a próxima sexta-feira (19) p...
# 419  2024-04-11 16:09:00  Basta dar uma olhada nos editoriais de moda pa...
# 420  2024-04-11 16:09:00  Basta dar uma olhada nos editoriais de moda pa...
# 719  2024-04-10 15:04:00  O cantor Zayn está em contagem regressiva para...
# 720  2024-04-10 15:04:00  O cantor Zayn está em contagem regressiva para...
#
#                                                Tópicos  \
# 117                                         João Doria
# 118  CNN Esportes, Futebol brasileiro, Futebol saud...
# 119                                                NaN
# 120                                         João Doria
# 121  CNN Esportes, Futebol brasileiro, Futebol saud...
# 122                                                NaN
# 419                          #CNNPop, Moda, Tendências
# 420                          #CNNPop, Moda, Tendências
# 719                                    #CNNPop, Música
# 720                                    #CNNPop, Música
#
#                                                   Link
# 117  https://www.cnnbrasil.com.br/politica/doria-pe...
# 118  https://www.cnnbrasil.com.br/esportes/goleiro-...
# 119  https://www.cnnbrasil.com.br/blogs/thais-hered...
# 120  https://www.cnnbrasil.com.br/politica/doria-pe...
# 121  https://www.cnnbrasil.com.br/esportes/goleiro-...
# 122  https://www.cnnbrasil.com.br/blogs/thais-hered...
# 419  https://www.cnnbrasil.com.br/lifestyle/franjas...
# 420  https://www.cnnbrasil.com.br/lifestyle/franjas...
# 719  https://www.cnnbrasil.com.br/entretenimento/za...
# 720  https://www.cnnbrasil.com.br/entretenimento/za...
